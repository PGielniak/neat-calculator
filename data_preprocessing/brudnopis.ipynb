# %%
import pandas as pd
csv_path = r"E:\src\neat-calculator\data_preprocessing\labels.csv"
labels_csv = pd.read_csv(csv_path)

# %%
labels_csv.head()
# Out:
#        timestamp     label
# 0  1767182183702  STANDING
# 1  1767182197313   WALKING
# 2  1767182202188  STANDING
# 3  1767182210924   WALKING
# 4  1767182215877  STANDING
